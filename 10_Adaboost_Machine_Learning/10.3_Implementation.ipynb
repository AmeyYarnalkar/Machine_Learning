# %% [markdown]
# ## Holiday Package Prediciton
#
# ### 1) Problem statement.
# "Trips & Travel.Com" company wants to enable and establish a viable business model to expand the customer base.
# One of the ways to expand the customer base is to introduce a new offering of packages. Currently, there are 5 types of packages the company is offering * Basic, Standard, Deluxe, Super Deluxe, King. Looking at the data of the last year, we observed that 18% of the customers purchased the packages. However, the marketing cost was quite high because customers were contacted at random without looking at the available information.
# The company is now planning to launch a new product i.e. Wellness Tourism Package. Wellness Tourism is defined as Travel that allows the traveler to maintain, enhance or kick-start a healthy lifestyle, and support or increase one's sense of well-being.
# However, this time company wants to harness the available data of existing and potential customers to make the marketing expenditure more efficient.
# ### 2) Data Collection.
# The Dataset is collected from https://www.kaggle.com/datasets/susant4learning/holiday-package-purchase-prediction
# The data consists of 20 column and 4888 rows.

# %%
from Configurations.imports import *

# %%
import warnings

# %%
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

# %%
# import the base
from Configurations.file_path import data_parent_path, base
file = data_parent_path / "travel.csv"

# %%
# read the data
df = pd.read_csv(file)
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# #### Data Cleaning

# %%
# Understanding the data
print(df.shape)

# checking the data type
df.info()
# Out:
# (4888, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
# checking the duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking for the duplicate columns
df.T.duplicated().sum()
# Out:
# np.int64(0)

# %%
# handling the missing values
df.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
# handling the column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ","_")
df
# Out:
#       customerid  prodtaken   age    typeofcontact  citytier  durationofpitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
# filling the missing values

#age
df["age"] = df["age"].fillna(df["age"].median())

#type of contact
df["typeofcontact"] = df["typeofcontact"].astype("category").fillna(df["typeofcontact"].mode())

#duration of the pitch
df["durationofpitch"] = df["durationofpitch"].fillna(df["durationofpitch"].mean())

# number of follow ups
df["numberoffollowups"] = df["numberoffollowups"].fillna(df["numberoffollowups"].mean())

# prefered property star
df["preferredpropertystar"] = df["preferredpropertystar"].dropna()

#number of the trips
df["numberoftrips"] = df["numberoftrips"].fillna(df["numberoftrips"].mean())

#number of children visiting 
df["numberofchildrenvisiting"] = df["numberofchildrenvisiting"].fillna(df["numberofchildrenvisiting"].mean())

# monthly income
df["monthlyincome"] = df["monthlyincome"].fillna(df["monthlyincome"].mean())

# %%
# remove the remaining the missing values
df = df.dropna()
df.isna().sum()
# Out:
# customerid                  0
# prodtaken                   0
# age                         0
# typeofcontact               0
# citytier                    0
# durationofpitch             0
# occupation                  0
# gender                      0
# numberofpersonvisiting      0
# numberoffollowups           0
# productpitched              0
# preferredpropertystar       0
# maritalstatus               0
# numberoftrips               0
# passport                    0
# pitchsatisfactionscore      0
# owncar                      0
# numberofchildrenvisiting    0
# designation                 0
# monthlyincome               0
# dtype: int64

# %%
# handling the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4837 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4837 non-null   int64
#  1   prodtaken                 4837 non-null   int64
#  2   age                       4837 non-null   float64
#  3   typeofcontact             4837 non-null   category
#  4   citytier                  4837 non-null   int64
#  5   durationofpitch           4837 non-null   float64
#  6   occupation                4837 non-null   object
#  7   gender                    4837 non-null   object
#  8   numberofpersonvisiting    4837 non-null   int64
#  9   numberoffollowups         4837 non-null   float64
#  10  productpitched            4837 non-null   object
#  11  preferredpropertystar     4837 non-null   float64
#  12  maritalstatus             4837 non-null   object
# ...

# %%
# handling the categorical
def convertToCategory():
    cols = ["occupation","gender","productpitched","maritalstatus","designation"]
    
    for col in cols:
        df[col] = df[col].astype("category")

convertToCategory()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4837 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4837 non-null   int64
#  1   prodtaken                 4837 non-null   int64
#  2   age                       4837 non-null   float64
#  3   typeofcontact             4837 non-null   category
#  4   citytier                  4837 non-null   int64
#  5   durationofpitch           4837 non-null   float64
#  6   occupation                4837 non-null   category
#  7   gender                    4837 non-null   category
#  8   numberofpersonvisiting    4837 non-null   int64
#  9   numberoffollowups         4837 non-null   float64
#  10  productpitched            4837 non-null   category
#  11  preferredpropertystar     4837 non-null   float64
#  12  maritalstatus             4837 non-null   category
# ...

# %%
# handling the extreme values and outliers
df["gender"] = df["gender"].str.replace("Fe Male","Female")
df["maritalstatus"] = df["maritalstatus"].str.replace("Single","Unmarried")

# %%
# Remove the unwanted column
df.drop("customerid", axis=1, inplace=True)

# %% [markdown]
# #### Feature Extraction

# %%
# total visiting
df["totalvising"] = df["numberofchildrenvisiting"] + df["numberofpersonvisiting"]
df.drop(columns=["numberofchildrenvisiting","numberofpersonvisiting"], axis=1, inplace=True)

# %%
def feature_types(df):

    # numerical features
    numerical_features = df.select_dtypes(
        include=['int64', 'float64']
    ).columns

    # categorical features
    categorical_features = df.select_dtypes(
        include=['object', 'category']
    ).columns

    # discrete features (numerical with small unique values)
    discrete_features = [
        col for col in numerical_features
        if df[col].nunique() < 25
    ]

    # continuous features (numerical but not discrete)
    continuous_features = [
        col for col in numerical_features
        if col not in discrete_features
    ]

    print("Numerical Features:", len(numerical_features))
    print("Categorical Features:", len(categorical_features))
    print("Discrete Features:", len(discrete_features))
    print("Continuous Features:", len(continuous_features))

    return numerical_features, categorical_features, \
           discrete_features, discrete_features
           
res = feature_types(df)
# Out:
# Numerical Features: 12
# Categorical Features: 6
# Discrete Features: 9
# Continuous Features: 3

# %%
numerical_features,categorical_features,discrete_features,discrete_features = res

# %% [markdown]
# #### Test and Train split of the dataset

# %%
# independent and dependent features
X = df.drop("prodtaken", axis=1) # independent feature

# %%
y = df["prodtaken"]

# %%
#test and train split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=24)
x_train.shape, x_test.shape
# Out:
# ((3869, 17), (968, 17))

# %%
numerical_features = [col for col in numerical_features if col != "prodtaken"]
numerical_features
# Out:
# ['age',
#  'citytier',
#  'durationofpitch',
#  'numberoffollowups',
#  'preferredpropertystar',
#  'numberoftrips',
#  'passport',
#  'pitchsatisfactionscore',
#  'owncar',
#  'monthlyincome',
#  'totalvising']

# %% [markdown]
# #### Encoding

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

oh_transformer = OneHotEncoder(drop="first")
num_transformer = StandardScaler()

preprocessor = ColumnTransformer([
    ("OneHotEncoder", oh_transformer, categorical_features),
    ("StandardScaler", num_transformer, numerical_features)
])

# %%
x_train = preprocessor.fit_transform(x_train)

# %%
x_test = preprocessor.transform(x_test)

# %% [markdown]
# #### Training

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
model = AdaBoostClassifier(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8522727272727273
# Precision: 0.7692307692307693
# Recall: 0.2808988764044944
# F1 Score: 0.411522633744856
# ROC AUC Score: 0.6309557673161712
#
# Confusion Matrix:
# [[775  15]
#  [128  50]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       790
#            1       0.77      0.28      0.41       178
#
#     accuracy                           0.85       968
#    macro avg       0.81      0.63      0.66       968
# weighted avg       0.84      0.85      0.82       968

# %%
y_prob = model.predict_proba(x_test)[:,1]
roc_auc_score(y_test, y_prob)
# Out:
# 0.8054081922912815

# %% [markdown]
# #### Hyper Parameter tuning

# %% [markdown]
# n_estimators: Int = 100,
#     *,
#     criterion: Literal['gini', 'entropy', 'log_loss'] = "gini",
#     max_depth: Int | None = None,
#     min_samples_split: float = 2,
#     min_samples_leaf: float = 1,
#     min_weight_fraction_leaf: Float = 0,
#     max_features: float | Literal['sqrt', 'log2'] = "sqrt",
#     max_leaf_nodes: Int | None = None,

# %%
rf_params = {
    "n_estimators":[100,250,500,1000],
    "algorithm": ['SAMME', 'SAMME.R']
}

# %%
from sklearn.model_selection import GridSearchCV
search = GridSearchCV(estimator=model, param_grid=rf_params, cv=5, scoring="accuracy",refit=True,verbose=True,n_jobs=-1)

# %%
search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# c:\Users\Ameyu\anaconda3\envs\ml_env\lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 20 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Ameyu\anaconda3\envs\ml_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Ameyu\anaconda3\envs\ml_env\lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
# ...

# %%
y_pred = search.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("ROC AUC Score:", roc_auc_score(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8522727272727273
# Precision: 0.7272727272727273
# Recall: 0.3146067415730337
# F1 Score: 0.4392156862745098
# ROC AUC Score: 0.6440122315460105
#
# Confusion Matrix:
# [[769  21]
#  [122  56]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       790
#            1       0.73      0.31      0.44       178
#
#     accuracy                           0.85       968
#    macro avg       0.80      0.64      0.68       968
# weighted avg       0.84      0.85      0.83       968

# %%
search.best_params_
# Out:
# {'algorithm': 'SAMME', 'n_estimators': 500}

# %%
y_prob = search.predict_proba(x_test)[:,1]
roc_auc_score(y_test, y_prob)
fpr, tpr, thresholds = roc_curve(y_test,y_pred)

# %%
plt.plot(fpr,tpr)
plt.plot([0,1],[0,1],'r--')
